# %% [markdown]
# **EJERCICIOS**
#
# - 1️⃣ Haz una descipción estadística de nuestro dataframe usando sidetable sobre las columnas `type` y `listed_in`.
#     - Qué tipo de títulos es más común en nuestro dataframe.
#
#     - Cuando filtres por `listed_in`, devuelve solo las que formen el 70% de los datos
#
#     - Agrupa por `listed_in` y `type` sacando unicamente los datos que compongan el 40% de los datos.
#
#     - Qué porcentaje de nulos tenemos
#
#     📌Después de sacar los resultados, debate con tu compañera la interpretación de los resultados obtenidos.

# %%
import pandas as pd
import sidetable

# %%
df = pd.read_csv("datos/netflix_titles.csv")
df.head()
# Out:
#       show_id     type                                   title  \
# 0  80190990.0    Movie                     Todo Sobre El Asado
# 1  81084225.0    Movie  Grego Rossello: Disculpe las molestias
# 2  81105406.0  TV Show                 Monzón: A Knockout Blow
# 3  81105522.0  TV Show                       No Time for Shame
# 4  81162089.0    Movie             GO! The Unforgettable Party
#
#                       director  \
# 0  Mariano Cohn, Gastón Duprat
# 1              Juani Libonatti
# 2                          NaN
# 3                          NaN
# 4             Mauro Scandolari
#
#                                                 cast    country  \
# 0                                   El Negro Álvarez  Argentina
# 1                                     Grego Rossello  Argentina
# 2  Jorge Román, Mauricio Paniagua, Carla Quevedo,...  Argentina
# 3                                   Santiago Artemis  Argentina
# 4  Pilar Pascual, José Gimenez Zapiola, Renata To...  Argentina
#
# ...

# %%
# 1️⃣ Haz una descipción estadística de nuestro dataframe usando sidetable.

df.stb.freq(["type"])
# Out:
#       type  count   percent  cumulative_count  cumulative_percent
# 0    Movie   4052  70.61694              4052            70.61694
# 1  TV Show   1686  29.38306              5738           100.00000

# %%
df.stb.freq(["listed_in"], thresh = 60)
# Out:
# C:\Users\agarc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sidetable\sidetable.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results[results[other_label] == False].append(
#                                             listed_in  count    percent  \
# 0                                       Documentaries    289   5.036598
# 1                                     Stand-Up Comedy    248   4.322063
# 2                        Dramas, International Movies    235   4.095504
# 3    Dramas, Independent Movies, International Movies    182   3.171837
# 4              Comedies, Dramas, International Movies    169   2.945277
# 5                 Documentaries, International Movies    133   2.317881
# 6                                            Kids' TV    130   2.265598
# ...

# %%
df.stb.freq(["listed_in", 'type'], thresh = 40)
# Out:
# C:\Users\agarc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sidetable\sidetable.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results[results[other_label] == False].append(
#                                             listed_in     type  count  \
# 0                                       Documentaries    Movie    289
# 1                                     Stand-Up Comedy    Movie    248
# 2                        Dramas, International Movies    Movie    235
# 3    Dramas, Independent Movies, International Movies    Movie    182
# 4              Comedies, Dramas, International Movies    Movie    169
# 5                 Documentaries, International Movies    Movie    133
# 6                                            Kids' TV  TV Show    130
# ...

# %%
# nulos

df.stb.missing()
# Out:
#                   missing  total    percent
# director             1663   5739  28.977174
# cast                  486   5739   8.468374
# date_added             10   5739   0.174246
# rating                  7   5739   0.121972
# negative_ratings        2   5739   0.034849
# show_id                 1   5739   0.017425
# type                    1   5739   0.017425
# title                   1   5739   0.017425
# country                 1   5739   0.017425
# release_year            1   5739   0.017425
# duration                1   5739   0.017425
# listed_in               1   5739   0.017425
# description             1   5739   0.017425
# positive_ratings        1   5739   0.017425
